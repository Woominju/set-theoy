# %% [markdown]
# <a href="https://colab.research.google.com/github/Woominju/set-theoy/blob/main/11_25_set_theory_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.판다스 라이브러리 불러오기
# 변형 불가능!

# %%
import pandas as pd

# %% [markdown]
# 2. 데이터 프레임 만들기

# %%
df = pd.DataFrame(
    {"d" : [8, 9, 10, 11],
     "e" : [12, 13, 14, 15 ],
     "f" : [16, 17, 18, 19]},
    index=[1, 2, 3, 4])

# %% [markdown]
# 3.데이터 프레임 출력하기

# %%
df
# Out:
#     d   e   f
# 1   8  12  16
# 2   9  13  17
# 3  10  14  18
# 4  11  15  19

# %% [markdown]
# 4. 데이터의 열 이름을 따로 지정해서 만들기

# %%
df = pd.DataFrame(
    [[8, 12, 16],
     [9, 13, 17],
     [10, 14, 18],
     [11, 15, 19]],
    index=[5, 6, 7, 8],
    columns=['d', 'e', 'f']
)

# %%
df
# Out:
#     d   e   f
# 5   8  12  16
# 6   9  13  17
# 7  10  14  18
# 8  11  15  19

# %% [markdown]
# 5. 인덱스가 두 개인 데이터 프레임 만들기

# %%
df = pd.DataFrame(
    { "d" : [8, 9, 10, 11],
     "e" : [12, 13, 14, 15 ],
     "f" : [16, 17, 18, 19]},
    index=pd.MultiIndex.from_tuples(
        [('e',3), ('e',4), ('f', 3), ('f', 4)],
        names=['n', 'v']))

# %%
df
# Out:
#       d   e   f
# n v
# e 3   8  12  16
#   4   9  13  17
# f 3  10  14  18
#   4  11  15  19

# %% [markdown]
# 6. 특정 열 값을 기준으로 정렬하기

# %%
df. sort_values('d', ascending=False)
# Out:
#       d   e   f
# n v
# f 4  11  15  19
#   3  10  14  18
# e 4   9  13  17
#   3   8  12  16

# %% [markdown]
# 7. 열 이름 변경하기

# %%
df.rename(columns={'f':'g'})
# Out:
#       d   e   g
# n v
# e 3   8  12  16
#   4   9  13  17
# f 3  10  14  18
#   4  11  15  19

# %% [markdown]
# 8.인덱스 값 초기화하기

# %%
df.reset_index()
# Out:
#    n  v   d   e   f
# 0  e  3   8  12  16
# 1  e  4   9  13  17
# 2  f  3  10  14  18
# 3  f  4  11  15  19

# %% [markdown]
# 9. 인덱스 순서대로 정렬하기

# %%
df.sort_index()
# Out:
#       d   e   f
# n v
# e 3   8  12  16
#   4   9  13  17
# f 3  10  14  18
#   4  11  15  19

# %% [markdown]
# 10. 특정 열 제거하기

# %%
df.drop(columns=['d','e'])
# Out:
#       f
# n v
# e 3  16
#   4  17
# f 3  18
#   4  19

# %% [markdown]
# 11.맨 위의 행 출력하기

# %%
df.head(2)
# Out:
#      d   e   f
# n v
# e 3  8  12  16
#   4  9  13  17

# %% [markdown]
# 12. 맨 아래 행 출력하기

# %%
df.tail(2)
# Out:
#       d   e   f
# n v
# f 3  10  14  18
#   4  11  15  19

# %% [markdown]
# 13. 특정 열의 값을 추출하기

# %%
df[df["d"]>10]
# Out:
#       d   e   f
# n v
# f 4  11  15  19

# %% [markdown]
# 14. 특정 열에 특정 값이 있을 경우 추출하기

# %%
df[df["d"]==10]
# Out:
#       d   e   f
# n v
# f 3  10  14  18

# %% [markdown]
# 15. 특정 열에 특정 값이 없을 경우 추출하기

# %%
df[df["d"]!=10]
# Out:
#       d   e   f
# n v
# e 3   8  12  16
#   4   9  13  17
# f 4  11  15  19

# %% [markdown]
# 16. 특정 열에 특정 숫자가 있는지 확인하기

# %%
df[df["d"].isin([10])]
# Out:
#       d   e   f
# n v
# f 3  10  14  18

# %% [markdown]
# 17. 특정 비율로 데이터 샘플링하기

# %%
df.sample(frac=0.5)
# Out:
#       d   e   f
# n v
# f 4  11  15  19
# e 3   8  12  16

# %% [markdown]
# 18. 특정 개수만큼 데이터 샘플링하기

# %%
df.sample(n=4)
# Out:
#       d   e   f
# n v
# f 3  10  14  18
# e 4   9  13  17
# f 4  11  15  19
# e 3   8  12  16

# %% [markdown]
# 19. 특정 열에서 큰 순서대로 불러오기

# %%
df.nlargest(2,'d')
# Out:
#       d   e   f
# n v
# f 4  11  15  19
#   3  10  14  18

# %% [markdown]
# 20. 특정 열에서 작은 순서대로 불러오기

# %%
df.nsmallest(2,'d')
# Out:
#      d   e   f
# n v
# e 3  8  12  16
#   4  9  13  17

# %% [markdown]
# 21. 인덱스의 범위로 불러오기

# %%
df.iloc[1:3]
# Out:
#       d   e   f
# n v
# e 4   9  13  17
# f 3  10  14  18

# %% [markdown]
# 21. 첫 인덱스를 지정해 불러오기

# %%
df. iloc[1:]
# Out:
#       d   e   f
# n v
# e 4   9  13  17
# f 3  10  14  18
#   4  11  15  19

# %% [markdown]
# 22. 마지막 인덱스를 지정해 불러오기

# %%
df. iloc[:2]
# Out:
#      d   e   f
# n v
# e 3  8  12  16
#   4  9  13  17

# %% [markdown]
# 24. 모든 인덱스 불러오기

# %%
df. iloc[:]
# Out:
#       d   e   f
# n v
# e 3   8  12  16
#   4   9  13  17
# f 3  10  14  18
#   4  11  15  19

# %% [markdown]
# 25. 특정 열을 지정해 가져오기

# %%
df[['d', 'e']]
# Out:
#       d   e
# n v
# e 3   8  12
#   4   9  13
# f 3  10  14
#   4  11  15

# %% [markdown]
# 26. 조건을 만족하는 열 가져오기

# %%
df.filter(regex='f')
# Out:
#       f
# n v
# e 3  16
#   4  17
# f 3  18
#   4  19

# %% [markdown]
# 27. 특정 문자가 포함되지 않는 열 가져오기

# %%
df.filter(regex='^wert')
# Out:
# Empty DataFrame
# Columns: []
# Index: [(e, 3), (e, 4), (f, 3), (f, 4)]

# %% [markdown]
# 28. 특정 행과 열을 지정해 가져오기

# %%
df.loc[:,'d':'f']
# Out:
#       d   e   f
# n v
# e 3   8  12  16
#   4   9  13  17
# f 3  10  14  18
#   4  11  15  19

# %% [markdown]
# 29. 인덱스로 특정 행과 열 가져오기

# %%
df.iloc[0:2,[0,1]]
# Out:
#      d   e
# n v
# e 3  8  12
#   4  9  13

# %% [markdown]
# 30. 특정 열에서 조건을 만족하는 행과 열 가져오기

# %%
df.loc[df['d'] > 10, ['d', 'f']]
# Out:
#       d   f
# n v
# f 4  11  19

# %% [markdown]
# 31. 인덱스를 이용해 특정 조건을 만족하는 값 불러오기

# %%
df.iat[2,1]
# Out:
# 14

# %%
df = pd.DataFrame(
    { "d" : [8, 9, 10, 11, 11],
     "e" : [12, 13, 14, 15, 15 ],
     "f" : [16, 17, 18, 19, 19]},
    index=pd.MultiIndex.from_tuples(
        [('e',3), ('e',4), ('f', 3), ('f', 4), ('f', 4)],
        names=['n', 'v']))

# %% [markdown]
# 32. 특정 열에 어떤 값이 몇 개 들어 있는지 알아보기

# %%
df['d'].value_counts()
# Out:
# 11    2
# 8     1
# 9     1
# 10    1
# Name: d, dtype: int64

# %% [markdown]
# 33. 데이터 프레임의 행이 몇 개인지 세어보기

# %%
len(df)
# Out:
# 5

# %% [markdown]
# 34. 데이터 프레임의 행과 열이 몇 개인지 세어보기

# %%
df.shape
# Out:
# (5, 3)

# %% [markdown]
# 35. 특정 열에 유니크한 값이 몇 개인지 세어보기

# %%
df['d'].nunique()
# Out:
# 4

# %% [markdown]
# 36. 데이터 프레임의 형태 한눈에 보기

# %%
df.describe()
# Out:
#               d         e         f
# count   5.00000   5.00000   5.00000
# mean    9.80000  13.80000  17.80000
# std     1.30384   1.30384   1.30384
# min     8.00000  12.00000  16.00000
# 25%     9.00000  13.00000  17.00000
# 50%    10.00000  14.00000  18.00000
# 75%    11.00000  15.00000  19.00000
# max    11.00000  15.00000  19.00000

# %% [markdown]
# 37. 중복된 값 제거하기

# %%
df= df.drop_duplicates()

# %%
df
# Out:
#       d   e   f
# n v
# e 3   8  12  16
#   4   9  13  17
# f 3  10  14  18
#   4  11  15  19

# %% [markdown]
# 38. 각 열의 합 보기

# %%
df.sum()
# Out:
# d    38
# e    54
# f    70
# dtype: int64

# %% [markdown]
# 39. 각 열의 값이 모두 몇 개인지 보기

# %%
df.count()
# Out:
# d    4
# e    4
# f    4
# dtype: int64

# %% [markdown]
# 40.각 열의 중간 값 보기

# %%
df.median()
# Out:
# d     9.5
# e    13.5
# f    17.5
# dtype: float64

# %% [markdown]
# 41. 특정 열의 평균값 보기

# %%
df['d'].mean()
# Out:
# 9.5

# %% [markdown]
# 42. 각 열의 25%, 75%에 해당하는 수 보기

# %%
df.quantile([0.25, 0.75])
# Out:
#           d      e      f
# 0.25   8.75  12.75  16.75
# 0.75  10.25  14.25  18.25

# %% [markdown]
# 43. 각 열의 최솟값 보기

# %%
df.min()
# Out:
# d     8
# e    12
# f    16
# dtype: int64

# %% [markdown]
# 44. 각 열의 최댓값 보기

# %%
df.max()
# Out:
# d    11
# e    15
# f    19
# dtype: int64

# %% [markdown]
# 45. 각 열의 표준편차 보기

# %%
df.std()
# Out:
# d    1.290994
# e    1.290994
# f    1.290994
# dtype: float64

# %% [markdown]
# 46. 데이터 프레임 각 값에 일괄 함수 적용하기

# %%
import numpy as np
df.apply(np.sqrt)
# Out:
#             d         e         f
# n v
# e 3  2.828427  3.464102  4.000000
#   4  3.000000  3.605551  4.123106
# f 3  3.162278  3.741657  4.242641
#   4  3.316625  3.872983  4.358899

# %%
df = pd.DataFrame(
    { "d" : [8, 9, 10, np.nan],
     "e" : [12, 13, np.nan, 15 ],
     "f" : [16, np.nan, 18, 19]},
    index=pd.MultiIndex.from_tuples(
        [('e',3), ('e',4), ('f', 3), ('f', 4)],
        names=['n', 'v']))

# %% [markdown]
# 47. null 값인지 확인하기

# %%
pd.isnull(df)
# Out:
#          d      e      f
# n v
# e 3  False  False  False
#   4  False  False   True
# f 3  False   True  False
#   4   True  False  False

# %% [markdown]
# 48.null 값이 아닌지 확인하기

# %%
pd.notnull(df)
# Out:
#          d      e      f
# n v
# e 3   True   True   True
#   4   True   True  False
# f 3   True  False   True
#   4  False   True   True

# %% [markdown]
# 49. null값이 있는 행 삭제하기

# %%
df_notnull = df.dropna()

df_notnull
# Out:
#        d     e     f
# n v
# e 3  8.0  12.0  16.0

# %% [markdown]
# 50. null 값을 특정 값으로 대체하기

# %%
df_fillna = df.fillna(15)
df_fillna
# Out:
#         d     e     f
# n v
# e 3   8.0  12.0  16.0
#   4   9.0  13.0  15.0
# f 3  10.0  15.0  18.0
#   4  15.0  15.0  19.0

# %% [markdown]
# 51.null 값을 특정 계산 결과로 대체하기

# %%
df_fillna_mean = df.fillna(df['d'].mean())

df = pd.DataFrame(
    { "d" : [8, 9, 10, 11],
     "e" : [12, 13, 14, 15 ],
     "f" : [16, 17, 18, 19]},
    index=pd.MultiIndex.from_tuples(
        [('e',3), ('e',4), ('f', 3), ('f', 4)],
        names=['n', 'v']))

# %% [markdown]
# 52. 조건에 맞는 새 열 만들기

# %%
df['sum'] = df['d']+df['e']+df['f']
df
# Out:
#       d   e   f  sum
# n v
# e 3   8  12  16   36
#   4   9  13  17   39
# f 3  10  14  18   42
#   4  11  15  19   45

# %% [markdown]
# 53. assign()을 이용해 조건에 맞는 새 열 만들기

# %%
df = df.assign(multiply=lambda df: df['e']*df['e']*df['f'])
df
# Out:
#       d   e   f  sum  multiply
# n v
# e 3   8  12  16   36      2304
#   4   9  13  17   39      2873
# f 3  10  14  18   42      3528
#   4  11  15  19   45      4275

# %% [markdown]
# 54. 숫자형 데이터를 구간으로 나누기

# %%
df['qcut'] = pd.qcut(df['d'], 2, labels=["3000이하", "3000이상"])
df
# Out:
#       d   e   f  sum  multiply    qcut
# n v
# e 3   8  12  16   36      2304  3000이하
#   4   9  13  17   39      2873  3000이하
# f 3  10  14  18   42      3528  3000이상
#   4  11  15  19   45      4275  3000이상

# %% [markdown]
# 55. 기준 값 이하와 이상을 모두 통일시키기

# %%
df['clip'] = df['d'].clip(lower=7, upper=8)
df
# Out:
#       d   e   f  sum  multiply    qcut  clip
# n v
# e 3   8  12  16   36      2304  3000이하     8
#   4   9  13  17   39      2873  3000이하     8
# f 3  10  14  18   42      3528  3000이상     8
#   4  11  15  19   45      4275  3000이상     8

# %% [markdown]
# 56. 최댓값 불러오기

# %%
df.max(axis=0)
# Out:
# d               11
# e               15
# f               19
# sum             45
# multiply      4275
# qcut        3000이상
# clip             8
# dtype: object

# %% [markdown]
# 57. 최솟값 불러오기

# %%
df.min(axis=0)
# Out:
# d                8
# e               12
# f               16
# sum             36
# multiply      2304
# qcut        3000이하
# clip             8
# dtype: object

# %%
df = pd.DataFrame({'D': {7: 'd', 8: 'e', 9: 'f'},
                   'E': {7: 8, 8: 10, 9: 12},
                   'F': {7: 9, 8: 11, 9: 13}})
df
# Out:
#    D   E   F
# 7  d   8   9
# 8  e  10  11
# 9  f  12  13

# %% [markdown]
# 58. 모든 열을 행으로 변환하기

# %%
pd.melt(df)
# Out:
#   variable value
# 0        D     d
# 1        D     e
# 2        D     f
# 3        E     8
# 4        E    10
# 5        E    12
# 6        F     9
# 7        F    11
# 8        F    13

# %% [markdown]
# 59. 하나의 열만 행으로 이동시키기

# %%
pd.melt(df, id_vars=['D'], value_vars=['E'])
# Out:
#    D variable  value
# 0  d        E      8
# 1  e        E     10
# 2  f        E     12

# %% [markdown]
# 60. 여러 개의 열을 행으로 이동시키기

# %%
df_melt = pd.melt(df, id_vars=['D'], value_vars=['E', 'F'])
df_melt
# Out:
#    D variable  value
# 0  d        E      8
# 1  e        E     10
# 2  f        E     12
# 3  d        F      9
# 4  e        F     11
# 5  f        F     13

# %% [markdown]
# 61. 특정 열의 값을 기준으로 새로운 열 만들기

# %%
df_pivot = df_melt.pivot(index='D', columns='variable', values='value')


df_pivot
# Out:
# variable   E   F
# D
# d          8   9
# e         10  11
# f         12  13

# %% [markdown]
# 62. 원래 데이터 형태로 되돌리기

# %%
df_origin = df_pivot.reset_index()
df_origin.columns.name = None
df_origin
# Out:
#    D   E   F
# 0  d   8   9
# 1  e  10  11
# 2  f  12  13

# %%
s1 = pd.Series(['d', 'e'])
s1
# Out:
# 0    d
# 1    e
# dtype: object

# %%
s2 = pd.Series(['f', 'g'])
s2
# Out:
# 0    f
# 1    g
# dtype: object

# %% [markdown]
# 63. 시리즈 데이터 합치기

# %%
pd.concat([s1, s2])
# Out:
# 0    d
# 1    e
# 0    f
# 1    g
# dtype: object

# %% [markdown]
# 64. 데이터를 병합할 때 새로운 인덱스 만들기

# %%
pd.concat([s1, s2], ignore_index=True)
# Out:
# 0    d
# 1    e
# 2    f
# 3    g
# dtype: object

# %% [markdown]
# 65. 계층적 인덱스를 추가하고 열 이름 지정하기

# %%
pd.concat([s1, s2],
          keys=['s1', 's2'],
          names=['Series name', 'Row ID'])
# Out:
# Series name  Row ID
# s1           0         d
#              1         e
# s2           0         f
#              1         g
# dtype: object

# %%
df1 = pd.DataFrame([['d', 4],
                    ['e', 5]],
                   columns=['letter', 'number'])
df1
# Out:
#   letter  number
# 0      d       4
# 1      e       5

# %%
df2 = pd.DataFrame([['f', 6],
                    ['g', 7]],
                   columns=['letter', 'number'])
df2
# Out:
#   letter  number
# 0      f       6
# 1      g       7

# %%
df3 = pd.DataFrame([['f', 6, 'rabbit'],
                    ['g', 7, 'hamster']],
                   columns=['letter', 'number', 'animal'])
df3
# Out:
#   letter  number   animal
# 0      f       6   rabbit
# 1      g       7  hamster

# %%
df4 = pd.DataFrame([['pig', 'summer'],
                    ['duck', 'winter']],
                   columns=['animal', 'name'])
df4
# Out:
#   animal    name
# 0    pig  summer
# 1   duck  winter

# %% [markdown]
# 66.데이터 프레임 합치기

# %%
pd.concat([df1, df2])
# Out:
#   letter  number
# 0      d       4
# 1      e       5
# 0      f       6
# 1      g       7

# %% [markdown]
# 67. 열의 수가 다른 두 데이터 프레임 합치기

# %%
pd.concat([df1, df3])
# Out:
#   letter  number   animal
# 0      d       4      NaN
# 1      e       5      NaN
# 0      f       6   rabbit
# 1      g       7  hamster

# %% [markdown]
# 68. 함께 공유하는 열만 합치기

# %%
pd.concat([df1, df3], join='inner')
# Out:
#   letter  number
# 0      d       4
# 1      e       5
# 0      f       6
# 1      g       7

# %% [markdown]
# 69. 열 이름이 서로다른 데이터 합치기

# %%
pd.concat([df1, df4], axis=1)
# Out:
#   letter  number animal    name
# 0      d       4    pig  summer
# 1      e       5   duck  winter

# %% [markdown]
# **데이터 병합하기**

# %%
adf= pd.DataFrame({"x1" : ["D", "E", "F"],
                   "x2": [4, 5, 6]})
adf
# Out:
#   x1  x2
# 0  D   4
# 1  E   5
# 2  F   6

# %%
bdf = pd.DataFrame({"x1" : ["D", "E", "G"],
                    "x3": ["T", "F", "T"]})
bdf
# Out:
#   x1 x3
# 0  D  T
# 1  E  F
# 2  G  T

# %%
cdf = pd.DataFrame({"x1" : ["E", "F", "G"],
                    "x2": [5, 6, 7]})
cdf
# Out:
#   x1  x2
# 0  E   5
# 1  F   6
# 2  G   7

# %% [markdown]
# 70. 왼쪽 열을 축으로 병합하기

# %%
pd.merge(adf, bdf, how='left', on='x1')
# Out:
#   x1  x2   x3
# 0  D   4    T
# 1  E   5    F
# 2  F   6  NaN

# %% [markdown]
# 71. 오른쪽 열을 축으로 병합하기

# %%
pd.merge(adf, bdf, how='right', on='x1')
# Out:
#   x1   x2 x3
# 0  D  4.0  T
# 1  E  5.0  F
# 2  G  NaN  T

# %% [markdown]
# 72. 공통 값만 병합하기

# %%
pd.merge(adf, bdf, how='inner', on='x1')
# Out:
#   x1  x2 x3
# 0  D   4  T
# 1  E   5  F

# %% [markdown]
# 73. 모든 값을 병합하기

# %%
pd.merge(adf, bdf, how='outer', on='x1')
# Out:
#   x1   x2   x3
# 0  D  4.0    T
# 1  E  5.0    F
# 2  F  6.0  NaN
# 3  G  NaN    T

# %% [markdown]
# 74. 특정한 열을 비교해서 공통 값이 존재하는 경우만 가져오기

# %%
adf[adf.x1.isin(bdf.x1)]
# Out:
#   x1  x2
# 0  D   4
# 1  E   5

# %% [markdown]
# 75. 공통 값이 존재하는 경우 해당 값을 제외하고 병합하기

# %%
adf[~adf.x1.isin(bdf.x1)]
# Out:
#   x1  x2
# 2  F   6

# %% [markdown]
# 76. 공통 값이 있는 것만 병합하기

# %%
pd.merge(adf, cdf)
# Out:
#   x1  x2
# 0  E   5
# 1  F   6

# %% [markdown]
# 77. 모두 병합하기

# %%
pd.merge(adf, cdf, how='outer')
# Out:
#   x1  x2
# 0  D   4
# 1  E   5
# 2  F   6
# 3  G   7

# %% [markdown]
# 78. 어디서 병합되었는지 표시하기

# %%
pd.merge(adf, cdf, how='outer', indicator=True)
# Out:
#   x1  x2      _merge
# 0  D   4   left_only
# 1  E   5        both
# 2  F   6        both
# 3  G   7  right_only

# %% [markdown]
# 79. 원하는 병합만 남기기

# %%
pd.merge(adf, cdf, how='outer', indicator=True).query('_merge=="left_only"')
# Out:
#   x1  x2     _merge
# 0  D   4  left_only

# %% [markdown]
# 80.merge 칼럼 없애기

# %%
pd.merge(adf, cdf, how='outer', indicator=True).query('_merge=="left_only"').drop(columns=['_merge'])
# Out:
#   x1  x2
# 0  D   4

# %% [markdown]
# **데이터 가공하기**

# %%
df = pd.DataFrame(
    {"d": [8, 9, 10, 11],
     "e": [12, 13, 14, 15],
     "f": [16, 17, 18, 19]},
    index=[4,5,6,7]
)
df
# Out:
#     d   e   f
# 4   8  12  16
# 5   9  13  17
# 6  10  14  18
# 7  11  15  19

# %% [markdown]
# 81. 행 전체를 두 칸 아래로 이동하기

# %%
df.shift(2)
# Out:
#      d     e     f
# 4  NaN   NaN   NaN
# 5  NaN   NaN   NaN
# 6  8.0  12.0  16.0
# 7  9.0  13.0  17.0

# %% [markdown]
# 82. 행 전채를 두 칸 위로 이동하기

# %%
df.shift(-2)
# Out:
#       d     e     f
# 4  10.0  14.0  18.0
# 5  11.0  15.0  19.0
# 6   NaN   NaN   NaN
# 7   NaN   NaN   NaN

# %% [markdown]
# 83. 첫 행부터 누적해서 더하기

# %%
df.cumsum()
# Out:
#     d   e   f
# 4   8  12  16
# 5  17  25  33
# 6  27  39  51
# 7  38  54  70

# %% [markdown]
# 84. 새 행과 이전 행을 비교하면서 최댓값 출력하기

# %%
df.cummax()
# Out:
#     d   e   f
# 4   8  12  16
# 5   9  13  17
# 6  10  14  18
# 7  11  15  19

# %% [markdown]
# 85. 새 행과 이전 행을 비교하면서 최솟값 출력하기

# %%
df.cummin()
# Out:
#    d   e   f
# 4  8  12  16
# 5  8  12  16
# 6  8  12  16
# 7  8  12  16

# %% [markdown]
# 86.첫 행부터 누적해서 곱하기

# %%
df.cumprod()
# Out:
#       d      e      f
# 4     8     12     16
# 5    72    156    272
# 6   720   2184   4896
# 7  7920  32760  93024
